# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print("TensorFlow:", tf.__version__)
print("Librosa:", librosa.__version__)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788281742.155279    1971 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788281742.539883    1971 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
DATASET_PATH = "/mnt/c/BirdProject/iBC53"

# %%
print("Dataset exists:", os.path.exists(DATASET_PATH))
# Out:
# Dataset exists: True

# %%
classes = sorted([
    folder for folder in os.listdir(DATASET_PATH)
    if os.path.isdir(os.path.join(DATASET_PATH, folder))
    and folder != "processed_audio"
])

print("Number of classes:", len(classes))

for i, cls in enumerate(classes):
    print(i, cls)
# Out:
# Number of classes: 52
# 0 Alexandrine Parakeet
# 1 Andaman Coucal
# 2 Andaman Drongo
# 3 Asian Barred Owlet
# 4 Asian Emerald Cuckoo
# 5 Asian Palm Swift
# 6 Baikal Bush Warbler
# 7 Black-bellied Plover
# 8 Black-browed Reed Warbler
# 9 Blue-winged Leafbird
# 10 Cachar Bulbul
# 11 Chestnut-capped Babbler
# 12 Chestnut-tailed Starling
# 13 Chinspot Wren-Babbler
# 14 Cinnamon Bittern
# 15 Citrine Wagtail
# 16 Collared Kingfisher
# 17 Grey Peacock-Pheasant
# 18 Grey-cheeked Tit
# 19 Grey-throated Babbler
# 20 Grey-throated Martin
# 21 Hill Partridge
# 22 Hume's Bar-tailed Scimitar Babbler
# 23 Indian Cuckoo
# 24 Jerdon's Leafbird
# 25 Jungle Myna
# 26 Large-billed Blue Flycatcher
# 27 Leafbird
# 28 Lineated Barbet
# 29 Long-billed Wren-Babbler
# 30 Long-tailed Shrike
# 31 Mrs Gould's Sunbird
# 32 Oriental Dollarbird
# 33 Pale Blue Flycatcher
# 34 Pale-chinned Blue Flycatcher
# 35 Plain Flowerpecker
# 36 Puff-throated Babbler
# 37 Pygmy Cupwing
# 38 Red-faced Liocichla
# ...

# %%
records = []

for species in classes:

    species_path = os.path.join(DATASET_PATH, species)

    for filename in os.listdir(species_path):

        if filename.lower().endswith(".wav"):

            records.append({
                "filepath": os.path.join(species_path, filename),
                "species": species
            })

df = pd.DataFrame(records)

print("Total recordings:", len(df))
print("Total classes:", df["species"].nunique())
# Out:
# Total recordings: 925
# Total classes: 52

# %%
df["species"].value_counts().sort_index()
# Out:
# species
# Alexandrine Parakeet                   28
# Andaman Coucal                         16
# Andaman Drongo                         20
# Asian Barred Owlet                     41
# Asian Emerald Cuckoo                    2
# Asian Palm Swift                        9
# Baikal Bush Warbler                     8
# Black-bellied Plover                    7
# Black-browed Reed Warbler               1
# Blue-winged Leafbird                    1
# Cachar Bulbul                           6
# Chestnut-capped Babbler                24
# Chestnut-tailed Starling               18
# Chinspot Wren-Babbler                   5
# Cinnamon Bittern                        4
# Citrine Wagtail                        19
# Collared Kingfisher                    23
# Grey Peacock-Pheasant                  11
# Grey-cheeked Tit                       24
# Grey-throated Babbler                  15
# Grey-throated Martin                    7
# Hill Partridge                         33
# ...
